# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import date

from prophet import Prophet
from prophet.diagnostics import performance_metrics
from prophet.plot import plot_cross_validation_metric
from prophet.diagnostics import cross_validation

from utils import extrair_feriados_prophet, calcular_metricas_completas, executar_pipeline_otimizacao
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = pd.read_csv('../data/train.csv')
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\Windows 10\AppData\Local\Temp\ipykernel_10064\2248642844.py:1: DtypeWarning: Columns (0: StateHoliday) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/train.csv')

# %%
df_sample = df[df['Store'] == 1]

# %%
espaco_hiperparametros = {
    'changepoint_prior_scale': [0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.1, 1.0, 10.0],
    'seasonality_mode': ['additive', 'multiplicative']
}

# %%
print(f"Iniciando otimização para a Loja 1 com {len(df_sample)} registros.")

executar_pipeline_otimizacao(
    df_bruto=df_sample,
    grid_parametros=espaco_hiperparametros,
    periodo_teste=30,       
    frequencia='D',      
    arquivo_log="resultados_otimizacao_loja_1.csv"
)
# Out:
# Iniciando otimização para a Loja 1 com 942 registros.
# Mapeando feriados e eventos diretamente dos dados históricos...
# Preparando features temporais...
# Corte temporal estabelecido em: 2015-07-01
# Treino: 912 linhas | Teste: 30 linhas
# Iniciando o Grid Search. Total de combinações a testar: 18
#
# [1/18] Executando configuração: {'changepoint_prior_scale': 0.01, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1}
# 20:22:08 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:09 - cmdstanpy - INFO - Chain [1] done processing
# [2/18] Executando configuração: {'changepoint_prior_scale': 0.01, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0}
# 20:22:10 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:10 - cmdstanpy - INFO - Chain [1] done processing
# [3/18] Executando configuração: {'changepoint_prior_scale': 0.01, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 10.0}
# 20:22:11 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:11 - cmdstanpy - INFO - Chain [1] done processing
# [4/18] Executando configuração: {'changepoint_prior_scale': 0.01, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1}
# 20:22:12 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:12 - cmdstanpy - INFO - Chain [1] done processing
# [5/18] Executando configuração: {'changepoint_prior_scale': 0.01, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0}
# 20:22:13 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:13 - cmdstanpy - INFO - Chain [1] done processing
# [6/18] Executando configuração: {'changepoint_prior_scale': 0.01, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 10.0}
# 20:22:14 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:14 - cmdstanpy - INFO - Chain [1] done processing
# [7/18] Executando configuração: {'changepoint_prior_scale': 0.1, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1}
# 20:22:14 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:15 - cmdstanpy - INFO - Chain [1] done processing
# [8/18] Executando configuração: {'changepoint_prior_scale': 0.1, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0}
# 20:22:15 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:16 - cmdstanpy - INFO - Chain [1] done processing
# [9/18] Executando configuração: {'changepoint_prior_scale': 0.1, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 10.0}
# 20:22:16 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:16 - cmdstanpy - INFO - Chain [1] done processing
# [10/18] Executando configuração: {'changepoint_prior_scale': 0.1, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1}
# 20:22:17 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:17 - cmdstanpy - INFO - Chain [1] done processing
# [11/18] Executando configuração: {'changepoint_prior_scale': 0.1, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0}
# 20:22:18 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:18 - cmdstanpy - INFO - Chain [1] done processing
# [12/18] Executando configuração: {'changepoint_prior_scale': 0.1, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 10.0}
# 20:22:19 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:19 - cmdstanpy - INFO - Chain [1] done processing
# [13/18] Executando configuração: {'changepoint_prior_scale': 0.5, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 0.1}
# 20:22:20 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:20 - cmdstanpy - INFO - Chain [1] done processing
# [14/18] Executando configuração: {'changepoint_prior_scale': 0.5, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 1.0}
# 20:22:21 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:21 - cmdstanpy - INFO - Chain [1] done processing
# [15/18] Executando configuração: {'changepoint_prior_scale': 0.5, 'seasonality_mode': 'additive', 'seasonality_prior_scale': 10.0}
# 20:22:22 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:22 - cmdstanpy - INFO - Chain [1] done processing
# [16/18] Executando configuração: {'changepoint_prior_scale': 0.5, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 0.1}
# 20:22:23 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:23 - cmdstanpy - INFO - Chain [1] done processing
# [17/18] Executando configuração: {'changepoint_prior_scale': 0.5, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 1.0}
# 20:22:24 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:24 - cmdstanpy - INFO - Chain [1] done processing
# [18/18] Executando configuração: {'changepoint_prior_scale': 0.5, 'seasonality_mode': 'multiplicative', 'seasonality_prior_scale': 10.0}
# 20:22:25 - cmdstanpy - INFO - Chain [1] start processing
# 20:22:25 - cmdstanpy - INFO - Chain [1] done processing
# Pipeline concluído com sucesso! Histórico salvo em: resultados_otimizacao_loja_1.csv

# %%
# plot1 = model.plot(forecast)

# %%
# plot2 = model.plot_components(forecast)

# %%
# plt.figure(figsize=(25, 5))
# plt.plot(df_final['ds'], df_final['y'], label='Realizado')
# plt.plot(df_final['ds'], df_final['yhat'], label='Previsto')
# plt.legend()
# plt.show()
